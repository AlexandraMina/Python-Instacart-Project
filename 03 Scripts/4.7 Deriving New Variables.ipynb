# %% [markdown]
# # Exercise 4.7

# %%
# Define function
def add_num(x,y):
    sum = x + y
    return sum

# %%
# Return function
add_num (9,11)
# Out:
# 20

# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
# Importing orders data - using os library
path = r'C:\Users\35196\Documents\Alexandra\Data Analytics Program\02 Immersion\4. Python Fundamentals for Data Analysts\Instacart Basket Analysis'

df_ords_prods_merge=pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
df=df_ords_prods_merge

# %%
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2398795        1    prior             2          3
# 2             2    473747        1    prior             3          3
# 3             3   2254736        1    prior             4          4
# 4             4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# 1) If-statements with user-defined functions

# %%
# Apply the following statements to an if-statement:
# If the item’s price is lower than or equal to $5, it will be labeled a “low-range product.”
# If the item’s price is above $5 but lower than or equal to $15, it will be labeled a “mid-range product.”
# If the item’s price is above $15, it will be labeled a “high-range product.”

def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2398795        1    prior             2          3
# 2             2    473747        1    prior             3          3
# 3             3   2254736        1    prior             4          4
# 4             4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %%
df_ords_prods_merge['price_range'] = df.apply(price_label, axis=1)

# %%
df_ords_prods_merge.describe()
# Out:
#        Unnamed: 0_x      order_id       user_id  order_number     order_dow  \
# count  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07  3.240486e+07
# mean   1.709858e+06  1.710745e+06  1.029372e+05  1.714230e+01  2.738867e+00
# std    9.864575e+05  9.872988e+05  5.946610e+04  1.753532e+01  2.090077e+00
# min    0.000000e+00  2.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.556370e+05  8.559470e+05  5.142200e+04  5.000000e+00  1.000000e+00
# 50%    1.709176e+06  1.711049e+06  1.026160e+05  1.100000e+01  3.000000e+00
# 75%    2.565919e+06  2.565499e+06  1.543890e+05  2.400000e+01  5.000000e+00
# max    3.421081e+06  3.421083e+06  2.062090e+05  9.900000e+01  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order    product_id  \
# count       3.240486e+07            3.032876e+07  3.240486e+07
# mean        1.342515e+01            1.110408e+01  2.559866e+04
# std         4.246380e+00            8.779064e+00  1.408400e+04
# ...

# %%
df_ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
df['prices'].max()
# Out:
# 14.8

# %% [markdown]
# 2. If-statements with the loc() functions

# %%
# Apply the following statements to an if-statement with loc() function:
# If the item’s price is lower than or equal to $5, it will be labeled a “low-range product.”
# If the item’s price is above $5 but lower than or equal to $15, it will be labeled a “mid-range product.”
# If the item’s price is above $15, it will be labeled a “high-range product.”

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range product     21860860
# Low-range product     10126321
# High-range product      417678
# Name: count, dtype: int64

# %% [markdown]
# 3. If-statements with for-loops

# %%
df_ords_prods_merge['order_dow'].value_counts(dropna=False)
# Out:
# order_dow
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# Create a new column “busiest day,” that will contain one of three different values: “Busiest day,” “Least busy,” and “Regularly busy.”

# %%
result = []

for value in df_ords_prods_merge['order_dow']:
  if value == 0:
    result.append('Busiest day')
  elif value == 4:
    result.append('Least busy')
  else:
    result.append('Regularly busy')

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
#Create a new column with result
df_ords_prods_merge['busiest_day']=result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # Task

# %%
# Checking price_label and busiest _day new columns

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2398795        1    prior             2          3
# 2             2    473747        1    prior             3          3
# 3             3   2254736        1    prior             4          4
# 4             4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %%
# Step 2 - Create "Busiest days" that correspond with the TWO busiest daysof the week
#          Create "Least days" that correspond with the TWO slowest days

result2 = []

for value in df_ords_prods_merge['order_dow']:
  if value == 0 or value == 1:
    result2.append('Busiest days')
  elif value == 3 or value == 4:
    result2.append('Slowest days')
  else:
    result2.append('Regularly busy')

# %%
result2
# Out:
# ['Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Slowest days',
#  'Regularly busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Slowest days',
#  'Slowest days',
#  'Regularly busy',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
#  'Regularly busy',
#  'Busiest days',
#  'Busiest days',
# ...

# %%
#Create a new column with result2 
df_ords_prods_merge['busiest_days']=result2

# %%
# Drop the previous variable, busiest_day
df_ords_prods_merge=df_ords_prods_merge.drop(['busiest_day'], axis=1)

# %%
df_ords_prods_merge.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  order_dow  \
# 0             0   2539329        1    prior             1          2
# 1             1   2398795        1    prior             2          3
# 2             2    473747        1    prior             3          3
# 3             3   2254736        1    prior             4          4
# 4             4    431534        1    prior             5          4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  Unnamed: 0_y product_name  aisle_id  department_id  prices  \
# ...

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32404859 entries, 0 to 32404858
# Data columns (total 19 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   Unnamed: 0_x            int64
#  1   order_id                int64
#  2   user_id                 int64
#  3   eval_set                object
#  4   order_number            int64
#  5   order_dow               int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   product_id              int64
#  9   add_to_cart_order       int64
#  10  reordered               int64
#  11  Unnamed: 0_y            int64
#  12  product_name            object
#  13  aisle_id                int64
#  14  department_id           int64
#  15  prices                  float64
#  16  _merge                  category
#  17  price_range             object
#  18  busiest_days            object
# dtypes: category(1), float64(2), int64(12), object(4)
# memory usage: 4.4+ GB

# %%
# Step 3 - Checking accuracy for the new column
df_ords_prods_merge['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regularly busy    12916111
# Busiest days      11864412
# Slowest days       7624336
# Name: count, dtype: int64

# %% [markdown]
# The sum of Busiest days, Slowest days and Regularly busy days are equal to the total entries.
# The sum of order_dow = 0 and order_dow = 1 are equal to the total Busiest days.
# The sum of order_dow = 3 and order_dow = 4 are equal to the total Slowest days.
# The sum of order_dow = 2,5,6 are equal to the total Regularly busy days.

# %%
# Step 4 - Create a new variable called  "busiest_period_of_day", by period of time "Most orders", "Average orders" and "Fewest orders"

# %%
# Checking value counts in "order_hour_of_day" column
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %% [markdown]
# I will consider:
#  - "Most orders"  when greater than 2M orders
#  - "Fewest orders" when lower than 250k orders
#  - "Average orders" all remaining hours

# %%
# Other option, using range() 
result_3 = []

for value in df_ords_prods_merge['order_hour_of_day']:
  if value in range(9, 17 ,1):
    result_3.append('Most orders')
  elif value in [0, 1, 5, 2, 4, 3]:
    result_3.append('Fewest orders')
  else:
    result_3.append('Average orders')

# %%
result_3 = []

for value in df_ords_prods_merge['order_hour_of_day']:
  if value in [10, 11, 14, 15, 13, 12, 16, 9, 17]:
    result_3.append('Most orders')
  elif value in [0, 1, 5, 2, 4, 3]:
    result_3.append('Fewest orders')
  else:
    result_3.append('Average orders')

# %%
result_3
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
# Create a new column with result3 
df_ords_prods_merge['busiest_period_of_day']=result_3

# %%
# Step 5 - Print the frequency for this new column
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       23205725
# Average orders     8602806
# Fewest orders       596328
# Name: count, dtype: int64

# %%
# Step 7 - Export dataframe as a pickle file
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'orders_products_combined_der.pkl'))
